# %%
import pandas as pd
import numpy as np
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from scipy import stats
from sklearn.preprocessing import StandardScaler

# %config Completer.use_jedi = False #for auto complete cod

# %%
class solidLR:
    def __init__(self,x,y):
        self.x=x
        self.y=y
        #variables que almacenan la normalizacion
        self.xn=0
        #modelo
        self.model=0
        pass
    def modelo_linear(self):
        self.xn=StandardScaler().fit_transform(self.x)
        self.xn=sm.add_constant(self.xn)
        self.model = sm.OLS(self.y,self.xn)
        self.model = self.model.fit()
    def significancia(self):
        return self.model.summary()

# %%
#leyendo base de datos
archivo = '../data/waste.csv'
df = pd.read_csv(archivo,sep=';')
df.drop(columns=['DEPARTAMENTO'],inplace=True)

# %%
df.head()
# Out:
#    NUMERO DE AMBIENTES  Numero de Personas  PAGO ULTIMO MES ELECTRICIDAD  \
# 0                  2.0                   3                         13.00
# 1                  4.0                   4                         35.00
# 2                  3.0                   3                         12.00
# 3                  3.0                   3                         58.00
# 4                  2.0                   3                         22.75
#
#    PAGO ULTIMO MES  PARA GLP   Gasto anual del Hogar  ALIMENTOS DENTRO   \
# 0                        35.0                9432.00             540.47
# 1                        35.0                8214.25             673.44
# 2                        35.0                7618.50             465.56
# 3                        36.7               10550.15             815.62
# 4                        34.0                7961.10             484.13
#
#    ALIMENTOS DENTRO BENEFICO  ALIMENTOS FUERA   ELECTRICIDAD   GLP  GN  \
# 0                     293.74            710.72            36   843   0
# 1                     680.61            399.92           196  1311   8
# 2                       0.00            497.98             4   671   0
# 3                     316.49            734.95            76  2169  21
# 4                     206.82            842.91             4   898   0
#
#    CARBON  LENA  OTRO  NO COCINAN      Organico    GPC
# 0       9   943   348          48   35573.81646  0.505
# 1       8  1001   481          44  126897.81080  0.523
# 2       1   787   670           2   34991.98743  0.522
# 3       5   253   643          61  211695.95090  0.485
# 4       2   899   378          14   81377.89874  0.538

# %%
X = df.drop(columns=['GPC'])
y = df['GPC']

# %%
est = solidLR(X,y)
est.modelo_linear()
est.significancia()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GPC   R-squared:                       0.728
# Model:                            OLS   Adj. R-squared:                  0.183
# Method:                 Least Squares   F-statistic:                     1.335
# Date:                Sun, 29 May 2022   Prob (F-statistic):              0.350
# Time:                        12:53:48   Log-Likelihood:                 54.466
# No. Observations:                  25   AIC:                            -74.93
# Df Residuals:                       8   BIC:                            -54.21
# Df Model:                          16
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.5118      0.010     52.852      0.000       0.489       0.534
# x1             0.0019      0.024      0.081      0.938      -0.053       0.057
# x2            -0.0174      0.029     -0.607      0.561      -0.083       0.049
# x3             0.0435      0.049      0.879      0.405      -0.071       0.157
# x4            -0.0136      0.022     -0.624      0.550      -0.064       0.037
# x5            -0.0138      0.033     -0.420      0.685      -0.089       0.062
# x6             0.0298      0.023      1.317      0.224      -0.022       0.082
# x7             0.0058      0.028      0.206      0.842      -0.059       0.070
# x8            -0.0063      0.016     -0.390      0.706      -0.044       0.031
# x9            -0.0128      0.059     -0.217      0.833      -0.148       0.123
# x10           -0.0358      0.042     -0.853      0.418      -0.133       0.061
# x11           -0.0257      0.044     -0.588      0.573      -0.126       0.075
# x12            0.0132      0.027      0.485      0.640      -0.050       0.076
# x13            0.0316      0.020      1.587      0.151      -0.014       0.078
# x14            0.0116      0.022      0.526      0.613      -0.039       0.062
# x15           -0.0024      0.027     -0.092      0.929      -0.064       0.059
# x16            0.0611      0.092      0.667      0.523      -0.150       0.272
# ==============================================================================
# Omnibus:                        0.044   Durbin-Watson:                   1.545
# Prob(Omnibus):                  0.978   Jarque-Bera (JB):                0.195
# Skew:                          -0.085   Prob(JB):                        0.907
# Kurtosis:                       2.602   Cond. No.                         30.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
